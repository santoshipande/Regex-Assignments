# %% [markdown]
# ### Task 4
# ### Registration/Referral id : AIRSS1150
# ### Name : Santoshi Dinesh Pande

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
data = pd.read_csv('student.csv')

# %% [markdown]
# ##### understanding the data

# %%
data.head()
# Out:
#    Unnamed: 0 race/ethnicity parental level of education         lunch  \
# 0           0        group B           bachelor's degree      standard
# 1           1        group C                some college      standard
# 2           2        group B             master's degree      standard
# 3           3        group A          associate's degree  free/reduced
# 4           4        group C                some college      standard
#
#   test preparation course  math percentage  reading score percentage  \
# 0                    none             0.72                      0.72
# 1               completed             0.69                      0.90
# 2                    none             0.90                      0.95
# 3                    none             0.47                      0.57
# 4                    none             0.76                      0.78
#
#    writing score percentage sex
# 0                      0.74   F
# 1                      0.88   F
# ...

# %%
data.tail()
# Out:
#      Unnamed: 0 race/ethnicity parental level of education         lunch  \
# 995         995        group E             master's degree      standard
# 996         996        group C                 high school  free/reduced
# 997         997        group C                 high school  free/reduced
# 998         998        group D                some college      standard
# 999         999        group D                some college  free/reduced
#
#     test preparation course  math percentage  reading score percentage  \
# 995               completed             0.88                      0.99
# 996                    none             0.62                      0.55
# 997               completed             0.59                      0.71
# 998               completed             0.68                      0.78
# 999                    none             0.77                      0.86
#
#      writing score percentage sex
# 995                      0.95   F
# ...

# %%
data.describe()
# Out:
#         Unnamed: 0  math percentage  reading score percentage  \
# count  1000.000000      1000.000000               1000.000000
# mean    499.500000         0.660890                  0.691690
# std     288.819436         0.151631                  0.146002
# min       0.000000         0.000000                  0.170000
# 25%     249.750000         0.570000                  0.590000
# 50%     499.500000         0.660000                  0.700000
# 75%     749.250000         0.770000                  0.790000
# max     999.000000         1.000000                  1.000000
#
#        writing score percentage
# count               1000.000000
# mean                   0.680540
# std                    0.151957
# min                    0.100000
# 25%                    0.577500
# 50%                    0.690000
# 75%                    0.790000
# max                    1.000000

# %%
data.shape
# Out:
# (1000, 9)

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math percentage',
#        'reading score percentage', 'writing score percentage', 'sex'],
#       dtype='object')

# %%
data.nunique()
# Out:
# Unnamed: 0                     1000
# race/ethnicity                    5
# parental level of education       6
# lunch                             2
# test preparation course           2
# math percentage                  81
# reading score percentage         72
# writing score percentage         77
# sex                               2
# dtype: int64

# %%
data['lunch'].unique()
# Out:
# array(['standard', 'free/reduced'], dtype=object)

# %% [markdown]
# ##### cleaning the database

# %%
data.isnull().sum()
# Out:
# Unnamed: 0                     0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math percentage                0
# reading score percentage       0
# writing score percentage       0
# sex                            0
# dtype: int64

# %%
student = data.drop(['race/ethnicity', 'parental level of education'], axis=1)

# %%
student.head()
# Out:
#    Unnamed: 0         lunch test preparation course  math percentage  \
# 0           0      standard                    none             0.72
# 1           1      standard               completed             0.69
# 2           2      standard                    none             0.90
# 3           3  free/reduced                    none             0.47
# 4           4      standard                    none             0.76
#
#    reading score percentage  writing score percentage sex
# 0                      0.72                      0.74   F
# 1                      0.90                      0.88   F
# 2                      0.95                      0.93   F
# 3                      0.57                      0.44   M
# 4                      0.78                      0.75   M

# %% [markdown]
# #### relationship analysis

# %%
corelation = student.corr()

# %%
sns.heatmap(corelation, xticklabels=corelation.columns , yticklabels= corelation.columns ,annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(student)

# %%
sns.relplot(x='math percentage', y = 'reading score percentage' , hue = 'lunch' , data= student)

# %%
sns.displot(student['math percentage'], bins =5)

# %%
sns.catplot(x='math percentage' , kind = 'box' , data = student)
